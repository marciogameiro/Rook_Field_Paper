# %% [markdown]
# # Install the software

# %%
# Install DSGRN
# !python -m pip install DSGRN

# %%
# Install the rook field paper code
# !python -m pip install git+https://github.com/marciogameiro/DSGRN_utils.git

# %% [markdown]
# # Import packages

# %%
import DSGRN
import DSGRN_utils

import time

# %% [markdown]
# # Examples Chapter 1 - Introduction

# %% [markdown]
# ## Example 1 (2D Example)

# %% [markdown]
# Define a DSGRN network

# %%
net_spec = """x1 : (~x1)(~x2)
              x2 : (~x1)(~x2)"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %% [markdown]
# Construct the parameter graph

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 87280405632

# %% [markdown]
# Choose a parameter index and get the corresponding parameter from the parametr graph

# %%
# Parameter index
par_index = 974

parameter = parameter_graph.parameter(par_index)

# %% [markdown]
# Compute the multi-valued map and the Morse graph

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 9.16 ms, sys: 742 µs, total: 9.9 ms
# Wall time: 9.5 ms

# %% [markdown]
# Plot the Morse graph

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# Plot the cell complex and the multi-valued map

# %%
DSGRN_utils.PlotMorseSets(morse_graph, stg, graded_complex)

# %% [markdown]
# Select a different parameter and compute the Morse graph

# %%
# Parameter index
par_index = 975

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 8.74 ms, sys: 508 µs, total: 9.24 ms
# Wall time: 9.92 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
DSGRN_utils.PlotMorseSets(morse_graph, stg, graded_complex)

# %% [markdown]
# Select a different parameter and compute the Morse graph

# %%
# Parameter index
par_index = 1054

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 8.81 ms, sys: 399 µs, total: 9.21 ms
# Wall time: 9.16 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
DSGRN_utils.PlotMorseSets(morse_graph, stg, graded_complex)

# %% [markdown]
# # Examples Chapter 16

# %% [markdown]
# ## Example 16.1.1 (2D Example)

# %%
net_spec = """x1 : x1 + x2
              x2 : (~x1) x2"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 1600

# %%
par_index = 752

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 8.46 ms, sys: 856 µs, total: 9.31 ms
# Wall time: 8.88 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
DSGRN_utils.PlotMorseSets(morse_graph, stg, graded_complex)

# %% [markdown]
# ## Example 16.1.2 (Saddle to saddle connections)

# %%
net_spec = """x : x + y + z
              y : (~x) (y + z)
              z : (~y) (x + z)"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 87280405632

# %%
par_index = 52718681992

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 220 ms, sys: 4.74 ms, total: 225 ms
# Wall time: 226 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# ## Example 16.2.1 (Periodic orbit 3D)

# %%
net_spec = """x : (x)(~y)(~z)
              y : (~x)(y)
              z : (~y)(z)"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 3600000

# %%
par_index = 2472287

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 117 ms, sys: 4.75 ms, total: 122 ms
# Wall time: 121 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# Plot the strongly connected component corresponding to the Morse node with the Conley index of a periodic orbit (Morse node 1)

# %%
morse_node = 1

DSGRN_utils.PlotMorseComponent(morse_graph, stg, graded_complex, morse_node, blowup=False)

# %% [markdown]
# ## Example 16.2.2 (Periodic orbit 5D)

# %%
net_spec = """x : (x)(~y)(~z)
              y : (~x)(y)
              z : (~y)(z)
              v : y
              w : w + z + v"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 13608000000

# %%
par_index = 5103162287

parameter = parameter_graph.parameter(par_index)

# %% [markdown]
# Use `level = 2` to compute Morse graph using this the multi-valued map $\mathcal{F}_2$

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter, level=2)
# Out:
# CPU times: user 9.97 s, sys: 76.2 ms, total: 10 s
# Wall time: 10.1 s

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
morse_node = 0

DSGRN_utils.PlotMorseComponent(morse_graph, stg, graded_complex, morse_node, blowup=False)

# %% [markdown]
# ## Example 16.2.3

# %%
net_spec = """x : (x)(~y)(~z)
              y : (~x)(y)
              z : (~y)(z)"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 3600000

# %%
par_index = 2023186

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 136 ms, sys: 9.39 ms, total: 145 ms
# Wall time: 145 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# Plot the strongly connected component corresponding to the Morse node 3

# %%
morse_node = 3

DSGRN_utils.PlotMorseComponent(morse_graph, stg, graded_complex, morse_node, blowup=False)

# %% [markdown]
# ## Example 16.3.2 (Simplicial flow example)

# %%
net_spec = """x : (x)(~y)(~z)
              y : (~x)(y)
              z : (~y)(z)"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 3600000

# %%
par_index = 2472286

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 117 ms, sys: 4.09 ms, total: 121 ms
# Wall time: 121 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# ## Example 16.3.3 (EMT Example 6D)

# %%
net_spec = """TGFb   : (~miR200)(~Ovol2)
              miR200 : (~Snail1)(~Zeb1)
              Snail1 : (~Snail1)(~miR34a)(TGFb)
              Ovol2  : (~Zeb1)
              Zeb1   : (~miR200)(~Ovol2)(Snail1)
              miR34a : (~Snail1)(~Zeb1)"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 4429771960320

# %%
par_index = 2684686006

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter, level=2)
# Out:
# CPU times: user 3min 15s, sys: 1.22 s, total: 3min 16s
# Wall time: 3min 20s

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# ## Example 16.4.1 (Trivial Conley index 2D)

# %%
net_spec = """x1 : x1 + x2
              x2 : (~x1) x2"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 1600

# %%
par_index = 47

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 8.17 ms, sys: 782 µs, total: 8.95 ms
# Wall time: 8.55 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
DSGRN_utils.PlotMorseSets(morse_graph, stg, graded_complex)

# %% [markdown]
# ## Example 16.4.2 (Trivial Conley index 3D)

# %%
net_spec = """x : x + y + z
              y : (~x) (y + z)
              z : (~y) (x + z)"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 87280405632

# %%
par_index = 65571607721

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 185 ms, sys: 4.59 ms, total: 189 ms
# Wall time: 190 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# ## Example 16.4.3 (Trivial Conley indices 3D)

# %%
par_index = 52717613010

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter)
# Out:
# CPU times: user 225 ms, sys: 5.66 ms, total: 231 ms
# Wall time: 232 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# ## Example 16.4.4 (Trivial Conley indices 6D)

# %%
net_spec = """TGFb   : (~miR200)(~Ovol2)
              miR200 : (~Snail1)(~Zeb1)
              Snail1 : (~Snail1)(~miR34a)(TGFb)
              Ovol2  : (~Zeb1)
              Zeb1   : (~miR200)(~Ovol2)(Snail1)
              miR34a : (~Snail1)(~Zeb1)"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Parameter graph size:', parameter_graph.size())
# Out:
# Parameter graph size: 4429771960320

# %%
par_index = 1739757491101

parameter = parameter_graph.parameter(par_index)

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(parameter, level=2)
# Out:
# CPU times: user 3min 31s, sys: 957 ms, total: 3min 32s
# Wall time: 3min 33s

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %% [markdown]
# ## Example 16.5.1 (Non DSGRN ramp system)

# %% [markdown]
# To compute with a non DSGRN ramp system it is necessary to first define a ramp system. Let's define four ramp functions and then define the ramp nonlinearity of the ramp system (`f_ramp`).

# %%
nu1_x = [7, 3, 7, 3]
theta1_x = [3, 5.1, 7.17]
h1_x = [0.15, 0.15, 0.15]
def fr1(x):
    return DSGRN_utils.ramp_function(x, nu1_x, theta1_x, h1_x)

nu1_y = [3.1, 4.9, 7.3]
theta1_y = [5.3, 6.1]
h1_y = [0.11, 0.11]
def gr1(y):
    return DSGRN_utils.ramp_function(y, nu1_y, theta1_y, h1_y)

nu2_x = [7.5, 5.5, 4]
theta2_x = [4, 5.5]
h2_x = [0.15, 0.15]
def fr2(x):
    return DSGRN_utils.ramp_function(x, nu2_x, theta2_x, h2_x)

nu2_y = [1.4, 5, 7.55, 9]
theta2_y = [4, 5.85, 7.55]
h2_y = [0.11, 0.11, 0.11]
def gr2(y):
    return DSGRN_utils.ramp_function(y, nu2_y, theta2_y, h2_y)

def f_ramp(x):
    return [fr1(x[0]) + gr1(x[1]), fr2(x[0]) + gr2(x[1])]

# %% [markdown]
# Define the parameters $\gamma$, $\theta$, and $h$ for the ramp system.

# %%
gamma1 = 2.0
gamma2 = 2.0

gamma = [gamma1, gamma2]
theta = [[theta1_x, theta1_y], [theta2_x, theta2_y]]
h = [[h1_x, h1_y], [h2_x, h2_y]]

# %% [markdown]
# Compute the wall labelling for the ramp system and the number of thresholds in each dimension.

# %%
labelling, num_thresholds = DSGRN_utils.ramp_system_wall_labelling(gamma, theta, h, f_ramp)

# %% [markdown]
# Compute the multi-valued map and the Morse graph from the wall labelling.

# %%
# %%time
morse_graph, stg, graded_complex = DSGRN_utils.ConleyMorseGraph(labelling=labelling, num_thresholds=num_thresholds)
# Out:
# CPU times: user 26.5 ms, sys: 2.38 ms, total: 28.9 ms
# Wall time: 28.3 ms

# %%
DSGRN_utils.PlotMorseGraph(morse_graph)

# %%
DSGRN_utils.PlotMorseSets(morse_graph, stg, graded_complex, fig_w=10, fig_h=10)
